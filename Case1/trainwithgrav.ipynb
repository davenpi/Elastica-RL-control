# %%
# !python policy_training_script.py
# Out:
# python3 logging_bio_args.py --total_timesteps=100000.0 --SEED=0 --timesteps_per_batch=8000 --algo=TRPO
# python3 logging_bio_args.py --total_timesteps=100000.0 --SEED=0 --timesteps_per_batch=8000 --algo=TRPO
# command started at: 2021-10-26 15:30:49.473554
# /Users/iandavenport/Desktop/research/venv/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %%
# !python policy_training_script.py
# Out:
# python3 logging_bio_args.py --total_timesteps=100000.0 --SEED=0 --timesteps_per_batch=8000 --algo=TRPO
# python3 logging_bio_args.py --total_timesteps=100000.0 --SEED=0 --timesteps_per_batch=8000 --algo=TRPO
# command started at: 2021-10-26 16:06:16.318261
# /Users/iandavenport/Desktop/research/venv/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %%
from stable_baselines import TRPO
# Out:
# /Users/iandavenport/Desktop/research/venv/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# ...

# %%
TRPO.load?
# Out:
# Signature: TRPO.load(load_path, env=None, custom_objects=None, **kwargs)
# Docstring:
# Load the model from file
#
# :param load_path: (str or file-like) the saved parameter location
# :param env: (Gym Environment) the new environment to run the loaded model on
#     (can be None if you only need prediction from a trained model)
# :param custom_objects: (dict) Dictionary of objects to replace
#     upon loading. If a variable is present in this dictionary as a
#     key, it will not be deserialized and the corresponding item
#     will be used instead. Similar to custom_objects in
#     `keras.models.load_model`. Useful when you have an object in
#     file that can not be deserialized.
# :param kwargs: extra arguments to change the model when loading
# File:      ~/Desktop/research/venv/lib/python3.7/site-packages/stable_baselines/common/base_class.py
# Type:      method

# %%
TRPO.load("policy-TRPO_3d-tracking_id-8000_0/parameters")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/7w/j5gl6mrn46jd965bzw_01wh40000gn/T/ipykernel_30710/2134394050.py in <module>
# ----> 1 TRPO.load("policy-TRPO_3d-tracking_id-8000_0/parameters")
#
# ~/Desktop/research/venv/lib/python3.7/site-packages/stable_baselines/common/base_class.py in load(cls, load_path, env, custom_objects, **kwargs)
#     941                                                                               kwargs['policy_kwargs']))
#     942
# --> 943         model = cls(policy=data["policy"], env=None, _init_setup_model=False)  # pytype: disable=not-instantiable
#     944         model.__dict__.update(data)
#     945         model.__dict__.update(kwargs)
#
# TypeError: 'NoneType' object is not subscriptable
